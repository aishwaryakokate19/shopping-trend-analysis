# %%
import pandas as pd
import numpy as np

# %%
shop = pd.read_csv("shopping_trends_updated.csv")
shop.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# In the above function we have fetched first 5 entries from the dataset we had got and we can view the fields
#
# **Customer ID**: Unique identifier for each customer.
#
# **Age**: Age of the customer.
#
# **Gender**: Gender of the customer.
#
# **Item Purchased**: The item purchased by the customer.
#
# **Category**: The category to which the purchased item belongs.
#
# **Purchase Amount (USD)**: The amount spent by the customer on the purchase.
#
# **Location**: The location of the customer.
#
# **Size**: The size of the purchased item.
#
# **Color**: The color of the purchased item.
#
# **Season**: The season associated with the purchase.
#
# **Review Rating**: Rating provided for the item (out of 5).
#
# **Subscription Status**: Indicates if the customer has a subscription.
#
# **Shipping Type**: The type of shipping used.
#
# **Discount Applied**: Whether a discount was applied to the purchase.
#
# **Promo Code Used**: Whether a promo code was used.
#
# **Previous Purchases**: Number of prior purchases by the customer.
#
# **Payment Method**: The method used for payment.
#
# **Frequency of Purchases**: How frequently the customer shops.

# %%
shop.shape
# Out:
# (3900, 18)

# %% [markdown]
# The dataset contains **3900 rows** and **19 columns**.
#
# **Observations**:
#
# **Rows**: Each row represents a unique purchase entry by a customer.
#
# **Columns**: These capture various attributes of the purchase, customer details, and product information.

# %%
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %% [markdown]
# Here are the observations based on the dataset information:
#
# **Dataset Summary**:
#
# **Number of Rows**: 3900 (entries).
#
# **Number of Columns**: 18 (after excluding the unnamed column).
#
# **Non-Null Counts**: All columns have 3900 non-null entries, indicating no missing values.
#
#
# **Data Types**:
#
# **int64**: 4 columns (e.g., Customer ID, Age, Purchase Amount (USD), Previous Purchases).
#
# **float64**: 1 column (Review Rating).
#
# **object**: 13 columns (categorical or text data, such as Gender, Item Purchased, Location, etc.).
#
# **Observations**:
# The dataset appears clean, with no missing values.
# Several columns are categorical and may need to be encoded for advanced analysis or machine learning tasks.
# Numeric columns like Purchase Amount (USD), Previous Purchases, and Review Rating could be useful for statistical insights.

# %%
shop.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# This output confirms that there are **no missing values** in any of the columns in the dataset. Every field has **a complete set of data** for all 3900 entries.
#
# **Observations**:
#
# **Data Completeness**: The dataset is clean in terms of missing data, so you can directly perform analyses without requiring
# imputation or data cleaning steps related to null values.
#
# **Analysis Potential**: All columns are ready for exploratory data analysis, visualization, and modeling.

# %%
shop.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# **Observations**:
#
#
# **Customer ID**:
#
# IDs are sequential, ranging from **1 to 3900**.
#
# This is likely just an identifier and not relevant for statistical analysis.
#
#
# **Age**:
#
# Ages range from **18 to 70 years**, with a **mean** age of **44 years**.
#
# The **standard deviation of 15.2 years** indicates a **wide age distribution**.
#
# The **25th percentile (31 years)** and **75th percentile (57 years)** suggest most customers fall between **young adults and seniors**.
#
#
# **Purchase Amount (USD)**:
#
# Purchase amounts range from **20 to 100 USD**, with a **mean of 59.76 USD**.
#
# The **standard deviation is 23.69 USD**, indicating **moderate variability in purchase amounts**.
#
# The **median (50th percentile)** purchase amount is **60 USD**, showing **symmetry around the mean**.
#
#
# **Review Rating**:
#
# Ratings range from **2.5 to 5.0**, with a **mean of 3.75**.
#
# The **standard deviation of 0.72** suggests relatively **small variation in customer ratings**.
#
# Most reviews are clustered between the 25th percentile (3.1) and the 75th percentile (4.4), indicating **moderately positive feedback**.
#
#
# **Previous Purchases**:
#
# The number of previous purchases ranges from **1 to 50**, with a **mean of 25.35**.
#
# The 25th percentile (13) and 75th percentile (38) suggest a **significant variation in customer loyalty** or frequency of shopping.
#
#
# **Inferences**:
#
# **Demographics**: The customer base includes a mix of younger and older shoppers, with a mean age skewing towards middle-aged individuals.
#
#
# **Purchasing Behavior**: The average spending amount and the number of previous purchases suggest a steady and moderately frequent shopping habit.
#
#
# **Customer Satisfaction**: The average review rating of 3.75 is fairly positive, though there might be room to improve customer satisfaction.
#
# **Loyalty Trends**: Customers with a high number of previous purchases might be loyal and valuable, worth targeting with special offers or rewards.

# %%
shop.describe(include="object")
# Out:
#        Gender Item Purchased  Category Location  Size  Color  Season  \
# count    3900           3900      3900     3900  3900   3900    3900
# unique      2             25         4       50     4     25       4
# top      Male         Blouse  Clothing  Montana     M  Olive  Spring
# freq     2652            171      1737       96  1755    177     999
#
#        Subscription Status  Shipping Type Discount Applied Promo Code Used  \
# count                 3900           3900             3900            3900
# unique                   2              6                2               2
# top                     No  Free Shipping               No              No
# freq                  2847            675             2223            2223
#
#        Payment Method Frequency of Purchases
# count            3900                   3900
# unique              6                      7
# top            PayPal         Every 3 Months
# freq              677                    584

# %% [markdown]
# **Observations**:
#
#
# **Gender**:
#
# **Unique values**: 2 (Male, Female).
#
# **Most common**: Male (2652 occurrences, ~68% of total).
#
# Suggests a **male-dominated customer base**.
#
#
# **Item Purchased**:
#
# **Unique items**: 25.
#
# **Most common item**: Blouse (171 purchases).
#
# Indicates **popular product categories** to focus on for marketing.
#
#
# **Category**:
#
# **Unique categories**: 4 (Clothing, Footwear, Accessories, Electronics).
#
# **Most common**: Clothing (1737 occurrences, ~44.5% of total).
#
# **Clothing dominates** the product mix, with other categories less represented.
#
#
# **Location**:
#
# **Unique locations**: 50.
#
# **Most common**: Montana (96 occurrences).
#
# Indicates **geographic diversity**, with Montana having the highest customer concentration.
#
#
# **Size**:
#
# **Unique values**: 4 (S, M, L, XL).
#
# **Most common**: M (1755 occurrences, ~45% of total).
#
# **Medium-size products** dominate purchases.
#
#
# **Color**:
#
# **Unique colors**: 25.
#
# **Most common**: Olive (177 occurrences).
#
# Suggests that earth tones like **olive might be trending** or preferred.
#
#
# **Season**:
#
# **Unique values**: 4 (Spring, Summer, Winter, Autumn).
#
# **Most common**: Spring (999 occurrences, ~25.6% of total).
#
# Could indicate a **seasonal shopping trend peaking in spring**.
#
#
# **Subscription Status**:
#
# **Unique values**: 2 (Yes, No).
#
# **Most common**: No (2847 occurrences, ~73% of total).
#
# **Majority of customers are non-subscribers**, offering an opportunity to promote subscriptions.
#
#
# **Shipping Type**:
#
# **Unique values**: 6.
#
# **Most common**: Free Shipping (675 occurrences).
#
# **Free shipping is popular** and could be a key factor in purchase decisions.
#
#
# **Discount Applied**:
#
# **Unique values**: 2 (Yes, No).
#
# **Most common**: No (2223 occurrences, ~57% of total).
#
# Discounts are applied in nearly 43% of transactions, suggesting an **opportunity to attract more customers** with promotions.
#
#
# **Promo Code Used**:
#
# **Unique values**: 2 (Yes, No).
#
# **Most common**: No (2223 occurrences, ~57% of total).
#
# Promo code use aligns closely with **discount application**.
#
#
# **Payment Method**:
#
# **Unique methods**: 6.
#
# **Most common**: PayPal (677 occurrences).
#
# Digital payment methods like **PayPal dominate**, suggesting convenience is a priority.
#
#
# **Frequency of Purchases**:
#
# **Unique frequencies**: 7.
#
# **Most common**: Every 3 Months (584 occurrences).
#
# Indicates that **quarterly shopping is the most common** frequency.
#
#
# **Inferences**:
#
#
# **Customer Trends**: The business caters largely to male customers who prefer clothing, especially medium-sized items in earth tones like olive.
#
# **Marketing Focus**:
# Expand subscription services, as most customers are not subscribers.
# Offer seasonal promotions, especially in spring, which appears to be the busiest season.
# Target regions with high purchase frequencies like Montana.
#
# **Customer Incentives**:
# Promote free shipping and discounts, as they are likely key drivers for purchases.
# Encourage quarterly buyers to shop more frequently through loyalty programs or incentives.

# %% [markdown]
# # DESCRIPTIVE ANALYSIS

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# ### **Q1.	What is the overall distribution of customer ages in the dataset?**

# %%
shop['Age'].value_counts()
# Out:
# Age
# 69    88
# 57    87
# 41    86
# 25    85
# 49    84
# 50    83
# 54    83
# 27    83
# 62    83
# 32    82
# 19    81
# 58    81
# 42    80
# 43    79
# 28    79
# 31    79
# 37    77
# 46    76
# 29    76
# 68    75
# 59    75
# 63    75
# 56    74
# 36    74
# 55    73
# 52    73
# 64    73
# 35    72
# 51    72
# 65    72
# 40    72
# 45    72
# 47    71
# 66    71
# 30    71
# 23    71
# 38    70
# 53    70
# 18    69
# 21    69
# 26    69
# 34    68
# 48    68
# 24    68
# 39    68
# 70    67
# 22    66
# 61    65
# 60    65
# 33    63
# 20    62
# 67    54
# 44    51
# Name: count, dtype: int64

# %%
shop['Age'].mean()
# Out:
# 44.06846153846154

# %%
shop['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
shop['Age_category'] = pd.cut(shop['Age'], bins= [0,15, 18 , 30 , 50 , 70] , labels= ['child' , 'teen' , 'Young Adults' ,'Middle-Aged Adults'
                                                                                             , 'old'] )
shop.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
fig = px.histogram(shop , y = 'Age' , x = 'Age_category')
fig.show()
# Out:
# <div>                            <div id="db12d227-754f-42dd-ad89-b7c54042dace" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db12d227-754f-42dd-ad89-b7c54042dace")) {                    Plotly.newPlot(                        "db12d227-754f-42dd-ad89-b7c54042dace",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Age_category=%{x}<br>sum of Age=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["old","Young Adults","Middle-Aged Adults","Young Adults","Middle-Aged Adults","Middle-Aged Adults","old","Young Adults","Young Adults","old","old","Young Adults","old","old","old","old","Young Adults","
# ...

# %% [markdown]
# **Observations**:
#
#
# **Dominant Groups**:
#
# Old and Middle Aged categories make up the majority of the customer base (~75.67% combined).
# These groups are likely key targets for marketing and promotions.
#
#
#
# **Young Adults**:
#
# They account for a significant share (~22.56%), indicating an important but secondary demographic.
#
#
#
# **Teenagers and Children**:
#
# Teens are a very small segment (~1.77%), and there are no customers in the Child category.
# This might be due to the nature of the products or the dataset's demographic focus.

# %% [markdown]
# ### **Q2 How does the average purchase amount vary across different product categories?**

# %%
shop['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
shop.groupby('Category')['Purchase Amount (USD)'].mean()
# Out:
# Category
# Accessories    59.838710
# Clothing       60.025331
# Footwear       60.255426
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
sns.barplot(shop , x = 'Category' , y = 'Purchase Amount (USD)')
# Out:
# <Axes: xlabel='Category', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# **Clothing**: 60.03 USD
#
# Clothing has the highest average purchase amount at 60.03 USD, which suggests that, on average, consumers spend the most on clothing. This could imply that clothing items may be priced higher or that customers tend to buy more expensive items in this category.
#
#
# **Footwear**: 60.26 USD
#
# Footwear has the second-highest purchase amount at 60.26 USD. Although this is slightly higher than clothing, the difference is marginal. This could mean that footwear items, on average, have comparable pricing to clothing, or that there are specific high-priced footwear items driving the average up.
#
#
# **Accessories**: 59.84 USD
#
# Accessories have a slightly lower average purchase amount at 59.84 USD. The difference with the other categories is small, indicating that the purchase amounts for accessories are fairly close to those of clothing and footwear. Accessories could have more budget-friendly options compared to clothing and footwear, which may explain this slight difference.
#
#
#
# **Outerwear**: 57.17 USD
#
# Outerwear has the lowest average purchase amount at 57.17 USD, which could be indicative of lower-priced outerwear items or fewer high-end purchases in this category. This category might be less expensive or have less variation in pricing compared to the other categories.
#
#
#
# **Key Observations**:
# Footwear and Clothing have similar purchase amounts, both above 60 USD, suggesting that these categories could have more premium offerings or higher-end customers.
#
# Accessories are close to Footwear and Clothing in terms of average spending, so even though it has more items, it doesn’t necessarily imply lower-value purchases.
#
# Outerwear is consistently lower in terms of the average purchase amount, possibly due to fewer luxury or higher-priced outerwear options in the shop.
#
# **Insights & Recommendations**:
#
# **Consider Increasing Premium Offerings for Outerwear**: Since outerwear has the lowest purchase amount, introducing higher-end or more expensive products could help increase the average sale value.
#
# **Footwear and Clothing**: Since these categories have similar higher purchase amounts, exploring strategies to improve customer engagement and increase sales in these categories would be effective. This could include promotions or introducing limited-edition products.
#
#
# **Accessories**: With a purchase amount slightly lower than Footwear and Clothing, focusing on bundling deals or offering a wider range of price points could be a good strategy for enhancing sales.

# %% [markdown]
# ### Q3 Which gender has the highest number of purchases?

# %%
sns.barplot(shop , x = 'Gender' , y = 'Purchase Amount (USD)')
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# **Observations**:
#
# There is not much difference between the purchasing amounts between Male and Female.
# Although females have it a little higher

# %% [markdown]
# ### Q4 What are the most commonly purchased items in each category?

# %%
shop.groupby('Category')['Item Purchased'].value_counts()
# Out:
# Category     Item Purchased
# Accessories  Jewelry           171
#              Sunglasses        161
#              Belt              161
#              Scarf             157
#              Hat               154
#              Handbag           153
#              Backpack          143
#              Gloves            140
# Clothing     Pants             171
#              Blouse            171
#              Shirt             169
#              Dress             166
#              Sweater           164
#              Socks             159
#              Skirt             158
#              Shorts            157
#              Hoodie            151
#              T-shirt           147
#              Jeans             124
# Footwear     Sandals           160
#              Shoes             150
#              Sneakers          145
#              Boots             144
# Outerwear    Jacket            163
#              Coat              161
# Name: count, dtype: int64

# %%
fig = px.histogram(shop , x = 'Item Purchased' , color = 'Category')
fig.show()
# Out:
# <div>                            <div id="f763f509-6091-46eb-926a-ff87136d7a61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f763f509-6091-46eb-926a-ff87136d7a61")) {                    Plotly.newPlot(                        "f763f509-6091-46eb-926a-ff87136d7a61",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Category=Clothing<br>Item Purchased=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Clothing","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clothing","offsetgroup":"Clothing","orientation":"v","showlegend":true,"x":["Blouse","Sweater","Jeans","Blouse","Shirt","Shorts","Shorts","Dress","Skirt","Dress","Sweater","Pants","Pants","Pants","Pants","Pants","Hoodie","Shorts","Dress","Dress","Pants",
# ...

# %% [markdown]
# Analysis of the number of items purchased in each category, focusing on the different products listed:
#
# **Accessories**:
#
# **Jewelry (171)**
# Jewelry is the most popular accessory, with the highest number of purchases. This indicates strong consumer interest in decorative or luxury items.
#
# **Sunglasses (161)**
# Sunglasses follow closely behind, highlighting that fashion-related accessories, such as sunglasses, have consistent demand.
#
# **Belt (161)**
# Belts are tied with sunglasses, suggesting that they are considered essential items in the accessory category, commonly bought alongside other fashion products.
#
# **Scarf (157)**
# Scarves have a moderate number of purchases, showing a steady demand for this functional yet fashionable accessory.
#
# **Hat (154)**
# Hats are also moderately purchased, likely contributing to the seasonal or trend-based nature of fashion accessories.
#
# **Handbag (153)**
# Handbags are closely tied with hats and scarves in terms of popularity, indicating that bags remain a staple accessory for many shoppers.
#
# **Backpack (143)**
# Backpacks show slightly lower demand compared to handbags, likely due to being more utilitarian than fashion-focused.
#
# **Gloves (140)**
# Gloves have the lowest purchase count in the accessories category, which may be due to seasonal demand, as they are typically purchased in colder months.
#
# **Clothing:**
#
# **Pants (171)**
# Pants lead the clothing category, reflecting their essential role in a wardrobe. They are likely to be a staple purchase for most consumers.
#
# **Blouse (171)**
# Blouses are tied with pants, suggesting that this item is popular, possibly for both casual and formal wear.
#
# **Shirt (169)**
# Shirts follow closely behind blouses, indicating strong demand for this versatile clothing item.
#
# **Dress (166)**
# Dresses are also fairly popular, which may point to a higher demand for formal or semi-formal wear.
#
# **Sweater (164)**
# Sweaters are purchased in large numbers, likely due to their seasonal appeal during cooler months.
#
# **Socks (159)**
# Socks are in moderate demand, as they are an essential but lower-priced item that tends to be purchased regularly.
#
# **Skirt (158)**
# Skirts show steady demand, which could be linked to seasonal trends or specific fashion preferences.
#
# **Shorts (157)**
# Shorts follow closely behind skirts, often bought for warmer weather or casual occasions.
#
# **Hoodie (151)**
# Hoodies are moderately purchased, suggesting they are popular for casual wear, especially during cooler months.
#
# **T-shirt (147)**
# T-shirts have a relatively lower purchase count, possibly due to being a basic staple that people already own in large quantities.
#
# **Jeans (124)**
# Jeans have the lowest number of purchases in this category, which might be due to consumer preference for other types of pants or a possible market saturation of jeans.
#
# **Footwear:**
#
# **Sandals (160)**
# Sandals are the most popular footwear item, likely due to their appeal in warmer climates or seasons.
#
# **Shoes (150)**
# Shoes follow closely, showing steady demand for general footwear that may be more versatile.
#
# **Sneakers (145)**
# Sneakers are moderately popular, possibly due to their combination of comfort and style, especially for active or casual wear.
#
# **Boots (144)**
# Boots have slightly fewer purchases, potentially due to their seasonal nature, typically being more popular in colder months.
#
# **Outerwear:**
# **Jacket (163)**
# Jackets lead the outerwear category, likely due to their versatility in both fashion and functionality across seasons.
#
# **Coat (161)**
# Coats show nearly as many purchases as jackets, which makes sense given that both are essential for colder weather.
#
# **Key Insights & Recommendations:**
#
# **Popular Items in Accessories**: Jewelry, sunglasses, and belts are top sellers, so a focus on stylish, high-demand accessories could boost sales.
#
# **Clothing Staples**: Pants, blouses, and shirts are high in demand. These essential items should be stocked regularly, and promotional strategies might be designed around them.
#
# **Footwear**: Sandals, shoes, and sneakers seem to be the top categories, which align with casual and comfortable styles. Offering a variety of styles or seasonal discounts could further increase sales.
#
# **Outerwear**: Jackets and coats are equally popular. Ensuring a variety of styles and promotions during cold weather could improve performance in this category.

# %% [markdown]
# ### Q5 Are there any specific seasons or months where customer spending is significantly higher?

# %%
shop['Season'].unique()
# Out:
# array(['Winter', 'Spring', 'Summer', 'Fall'], dtype=object)

# %%
shop[shop['Season'] == 'Summer'].value_counts().sum()
# Out:
# 955

# %%
shop[shop['Season'] == 'Winter'].value_counts().sum()
# Out:
# 971

# %%
shop[shop['Season'] == 'Spring'].value_counts().sum()
# Out:
# 999

# %%
shop[shop['Season'] == 'Fall'].value_counts().sum()
# Out:
# 975

# %%
fig = px.histogram(shop , x = 'Season' , range_y= [200 , 1500] )

fig.show()
# Out:
# <div>                            <div id="a3f0a9ad-9e0d-48d1-888c-555375515126" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3f0a9ad-9e0d-48d1-888c-555375515126")) {                    Plotly.newPlot(                        "a3f0a9ad-9e0d-48d1-888c-555375515126",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Season=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Winter","Winter","Spring","Spring","Spring","Summer","Fall","Winter","Summer","Spring","Fall","Winter","Winter","Spring","Winter","Winter","Spring","Winter","Summer","Summer","Winter","Winter","Summer","Winter","Fall","Summer","S
# ...

# %% [markdown]
# **Seasonal Spending Breakdown:**
#
#
# **Spring: 999 (Highest)**
# Spring has the highest customer spending, suggesting that shoppers may be more active during this season, possibly due to the availability of new collections or a greater variety of products suitable for spring weather. Additionally, it could be a time for fashion refreshes, with lighter clothing, accessories, and outerwear, driving more sales.
#
# **Winter: 971**
# Winter spending is slightly lower than spring, but still significant. This could be due to higher-ticket items such as jackets, coats, and boots, as well as seasonal needs like sweaters, scarves, and gloves. Despite the potentially higher price points for winter apparel, customers may purchase fewer but more expensive items compared to spring.
#
# **Fall: 975**
# Fall is very close to winter in terms of spending, likely due to the overlap in apparel items like jackets, boots, and sweaters. Fall is also a transitional period for fashion, with a mix of lighter and heavier clothing, which could encourage more spending across categories.
#
# **Summer: 955 (Lowest)**
# Summer has the lowest spending, which might be because the products in demand during this season—such as sandals, t-shirts, shorts, and other lighter items—are generally less expensive compared to winter and fall products. Additionally, some customers may not spend as much on clothing or accessories during this period, opting for budget-friendly or seasonal essentials.
#
# **Key Observations:**
# Spring leads in spending, possibly due to a combination of new fashion arrivals, lighter clothing, and a high level of consumer activity as people update their wardrobes for the season.
# Winter and Fall are close in terms of spending, with higher-priced outerwear likely driving up sales in these colder months.
# Summer sees the lowest spending, possibly due to the nature of products being less expensive and fewer high-ticket items being purchased.
#
#
# **Insights & Recommendations:**
#
#
# **Focus on Promotions in Spring:** Since spring sees the highest customer spending, it would be strategic to have promotions or new collection launches during this season to maximize sales.
#
# **Winter and Fall Sales Strategy:** While winter and fall both see high spending, focusing on premium outerwear, boots, and cold-weather accessories could increase sales during these months.
#
# **Summer Product Strategy:** Although summer has lower spending, you could promote sales or offer discounts on essential summer items to encourage more purchases. Alternatively, focus on bundling deals (e.g., pairing sandals with sunglasses or t-shirts with shorts) to increase customer spending.

# %% [markdown]
# ### Q6 What is the average rating given by customers for each product category?¶

# %%
shop_groupby = shop.groupby('Category')['Review Rating'].mean().reset_index()

# %%
fig = px.bar(shop_groupby ,x= 'Category' , y = 'Review Rating' )
fig.show()
# Out:
# <div>                            <div id="e407e682-0651-43c2-bb94-37551c230140" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e407e682-0651-43c2-bb94-37551c230140")) {                    Plotly.newPlot(                        "e407e682-0651-43c2-bb94-37551c230140",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Review Rating=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Accessories","Clothing","Footwear","Outerwear"],"xaxis":"x","y":[3.768629032258065,3.7231433506044906,3.790651085141903,3.746913580246914],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"
# ...

# %% [markdown]
# **Average Ratings:**
#
#
# **Footwear: 3.790 (Highest Rating)**
# Footwear has the highest average rating of 3.790. This suggests that, on average, customers are more satisfied with their footwear purchases compared to other categories. It could indicate good product quality, comfort, or customer satisfaction in terms of fit and style. Footwear often meets the expectations of consumers, which could lead to higher ratings.
#
# **Accessories: 3.768**
# Accessories have a slightly lower average rating than footwear, but still high at 3.768. This shows that accessories are generally well-received, though there might be a slightly lower level of satisfaction compared to footwear. This could be due to issues like style preferences, size variations, or product durability.
#
# **Outerwear: 3.746**
# Outerwear has a slightly lower rating than accessories and footwear. This may suggest that while outerwear is generally appreciated, it might sometimes fall short of customer expectations. Possible reasons could include sizing issues, material quality, or mismatches between the product design and customer needs.
#
# **Clothing: 3.723 (Lowest Rating)**
# Clothing has the lowest rating of 3.723, though it is still relatively high. This could indicate that, while customers generally like the clothing items, there may be a few issues such as fit, style, or fabric quality that could impact the overall satisfaction. Clothing could also be subject to more varied tastes and preferences, which might explain the slightly lower rating.
#
# **Key Insights:**
#
#
# Footwear stands out as the category with the highest customer satisfaction, suggesting that the products in this category meet or exceed customer expectations.
#
# Accessories and outerwear follow closely behind, showing that while customers are generally satisfied, there may be room for improvement, particularly in areas like sizing or material choices.
#
# Clothing has the lowest rating, which might imply more opportunities for improvement in terms of product fit, fabric, or design to meet customer preferences.
#
#
# **Recommendations:**
#
#
# **For Footwear**: Since it has the highest ratings, it would be beneficial to continue focusing on the features that contribute to customer satisfaction, such as comfort, variety, and durability.
#
# **For Accessories**: While the ratings are good, ensuring that products are available in a range of styles and sizes, and improving product quality or design, could help boost customer satisfaction further.
# For Outerwear: Addressing potential issues related to sizing, material quality, or fit could lead to higher ratings in this category.
#
# **For Clothing**: Analyzing customer feedback more closely to understand dissatisfaction points—such as fit, fabric, or design—could help improve the ratings for this category.

# %% [markdown]
# ### Q7 Are there any notable differences in purchase behavior between subscribed and non-subscribed customers?

# %%
shop['Subscription Status'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
shop.groupby('Subscription Status')['Purchase Amount (USD)'].mean()
# Out:
# Subscription Status
# No     59.865121
# Yes    59.491928
# Name: Purchase Amount (USD), dtype: float64

# %%
sns.barplot(shop  , x = 'Subscription Status' , y = 'Purchase Amount (USD)')
# Out:
# <Axes: xlabel='Subscription Status', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# **Subscription Status:**
#
#
# **No (59.87%):**
# This indicates that a slightly higher percentage of customers are non-subscribed. Non-subscribed customers could still be purchasing items regularly, but they may not be benefiting from any special offers, discounts, or exclusive content that a subscription could offer. Given the high percentage of "No" customers, this group might represent the general retail customers who make standard purchases without any loyalty program or subscription service.
#
# **Yes (59.49%):**
# The percentage of subscribed customers is marginally lower, suggesting that a substantial portion of the customer base has opted for some form of subscription or membership. These customers are likely benefiting from incentives such as discounts, exclusive access to certain products, or other loyalty rewards.
#
# **Key Insights:**
#
#
# **Very Close in Proportions:** The percentages for both subscription statuses are very close, with non-subscribed customers having a slight edge. This suggests that the sales from both groups are nearly balanced, which could point to a well-structured offering that attracts customers both with and without subscriptions.
#
# **Potential Impact of Subscription:** While the overall percentage of subscribed customers is marginally lower, it’s possible that the "Yes" group could be generating higher sales due to the value they perceive in the subscription (discounts, perks, etc.). These customers may make more frequent purchases or spend more per transaction to benefit from the advantages of being a subscriber.
#
# **Retention vs. Acquisition:** Non-subscribed customers could represent new or casual shoppers, while the subscribed customers might be more loyal and engaged with the brand. The key to growing sales could be converting non-subscribed customers into subscribers through incentives, exclusive deals, or showcasing the value of the subscription program.
#
# **Recommendations:**
#
#
# **Focus on Retention for Subscribed Customers:**
# Since subscribed customers may already bring in consistent sales, it would be strategic to continue providing them with additional value (exclusive offers, loyalty points, etc.) to keep them engaged and encourage repeat purchases.
#
# **Convert Non-Subscribed Customers:**
# A slightly higher percentage of customers are not subscribed. A targeted marketing campaign emphasizing the benefits of subscription—such as discounts, early access to new products, or exclusive deals—could encourage these customers to subscribe and increase their spending.
#
# **Explore the Impact of Subscription on Sales:**
# If available, comparing the average purchase amounts of subscribed vs. non-subscribed customers could offer deeper insights. Subscribed customers might be spending more per transaction, and increasing the overall subscription rate could lead to higher sales.
#
# **Customer Experience and Engagement:**
# Make the shopping experience more appealing for both groups. For non-subscribed customers, create an easier path to subscription, while for subscribed customers, offer rewards or perks that make the subscription feel more valuable.

# %% [markdown]
# ### Q8 Which payment method is the most popular among customers?¶

# %%
shop.groupby('Payment Method')['Purchase Amount (USD)'].mean().sort_values(ascending= False)
# Out:
# Payment Method
# Debit Card       60.915094
# Credit Card      60.074516
# Bank Transfer    59.712418
# Cash             59.704478
# PayPal           59.245199
# Venmo            58.949527
# Name: Purchase Amount (USD), dtype: float64

# %%
shop_groupby = shop.groupby('Payment Method')['Purchase Amount (USD)'].mean().reset_index()

# %%
fig = px.bar(shop_groupby , x = 'Payment Method' , y = 'Purchase Amount (USD)')
fig.show()
# Out:
# <div>                            <div id="0085e80e-8f80-4fa6-b1b7-31b371aaf270" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0085e80e-8f80-4fa6-b1b7-31b371aaf270")) {                    Plotly.newPlot(                        "0085e80e-8f80-4fa6-b1b7-31b371aaf270",                        [{"alignmentgroup":"True","hovertemplate":"Payment Method=%{x}<br>Purchase Amount (USD)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bank Transfer","Cash","Credit Card","Debit Card","PayPal","Venmo"],"xaxis":"x","y":[59.712418300653596,59.7044776119403,60.07451564828614,60.91509433962264,59.24519940915805,58.94952681388013],"yaxi
# ...

# %% [markdown]
# **Payment Method Analysis:**
#
#
# **Debit Card (60.92%)**
#
# Debit cards have the highest share of sales, indicating that most customers prefer paying directly from their bank accounts. This could be due to the convenience, safety, and no need for credit checks that debit cards offer. It also suggests that a significant portion of the customer base either doesn’t use credit or prefers using funds that they already have in their bank accounts.
# **Credit Card (60.07%)**
#
# Credit cards come in second, showing that many customers also prefer using credit for purchases. This is likely due to the flexibility credit cards provide in terms of deferred payments, rewards points, and purchase protections. The close percentage between debit and credit cards suggests that both are highly favored, but the slight edge to debit card usage may reflect a preference for direct payments without borrowing.
# **Bank Transfer (59.71%)**
#
# Bank transfers are used less frequently than debit and credit cards but still account for a significant share of payments. This could indicate that some customers prefer transferring funds directly from their bank accounts, possibly for larger transactions or when they want to avoid using cards altogether. The slight decrease in usage compared to debit and credit cards could be due to the slower processing time or lack of immediate confirmation in some cases.
# **Cash (59.70%)**
#
# Cash payments are close in percentage to bank transfers, suggesting that some customers still prefer paying with physical money, especially in brick-and-mortar stores. However, with the rise of digital payments, cash usage has been in decline. Cash payments could represent customers who may not have access to digital banking or prefer to keep their spending within a set budget.
# **PayPal (59.25%)**
#
# PayPal has a relatively lower percentage compared to the previous methods. It’s popular for online transactions, especially for customers who prefer not to share card details directly with merchants. PayPal’s slightly lower share might suggest that while it’s commonly used, it’s not as favored as debit or credit cards in the context of your sales data.
# **Venmo (58.95%)**
#
# Venmo, which is more commonly used in the United States for peer-to-peer transactions, has the lowest sales share in this data. It could be used for smaller purchases or among a younger demographic, as Venmo is popular for casual, quick payments between friends or acquaintances. Its relatively low percentage might indicate that it is less commonly used for business transactions compared to other payment methods.
#
#
# **Key Insights:**
#
# **Debit and Credit Cards Dominate**: Debit and credit cards are by far the most popular payment methods, which makes sense given their widespread use and ease of transaction.
#
# **Bank Transfers and Cash Show Moderate Use**: These payment methods are still quite relevant but less frequently used in comparison to cards. Bank transfers might be more common for larger purchases, while cash usage suggests that some customers are less inclined toward digital payment methods.
#
# **PayPal and Venmo Show Lower Engagement**: PayPal has a somewhat lower share, possibly due to people using more traditional methods for purchases, while Venmo seems to be least used for transactions, which could be attributed to its niche audience.
#
#
# **Recommendations**:
#
# **Optimize for Card Payments**: Since debit and credit cards dominate, ensuring that these methods are as smooth and secure as possible is essential. Offering incentives or rewards for card use could further increase sales.
#
# **Support Bank Transfers for Larger Purchases**: For customers who prefer bank transfers, offering additional support or even discounts for using this method could be an effective strategy to boost sales.
#
# **Enhance Digital Payment Options**: Consider increasing the availability of PayPal and Venmo as payment options, especially if targeting younger audiences who prefer mobile wallets and peer-to-peer payment methods.
#
# **Cash Payments**: While cash is still in use, consider promoting digital payments more, especially for online purchases. You could offer discounts for customers who use digital payments over cash to encourage more streamlined transactions.**

# %% [markdown]
# ### Q9 Do customers who use promo codes tend to spend more than those who don't?

# %%
shop_groupby  = shop.groupby('Promo Code Used')['Purchase Amount (USD)'].sum().reset_index()

# %%
fig = px.sunburst(shop , path=['Gender' , 'Promo Code Used'] , values='Purchase Amount (USD)')
fig.show()
# Out:
# <div>                            <div id="d2f1cdc0-f05b-41eb-9bce-622a3fc9f551" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2f1cdc0-f05b-41eb-9bce-622a3fc9f551")) {                    Plotly.newPlot(                        "d2f1cdc0-f05b-41eb-9bce-622a3fc9f551",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Purchase Amount (USD)=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Female/No","Male/No","Male/Yes","Female","Male"],"labels":["No","No","Yes","Female","Male"],"name":"","parents":["Female","Male","Male","",""],"values":[75191,58479,99411,75191,157890],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"
# ...

# %%
fig  =  px.bar(shop_groupby , x= 'Promo Code Used' , y = 'Purchase Amount (USD)')
fig.show()
# Out:
# <div>                            <div id="d907a5f3-6064-4773-b242-9e727caa05da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d907a5f3-6064-4773-b242-9e727caa05da")) {                    Plotly.newPlot(                        "d907a5f3-6064-4773-b242-9e727caa05da",                        [{"alignmentgroup":"True","hovertemplate":"Promo Code Used=%{x}<br>Purchase Amount (USD)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["No","Yes"],"xaxis":"x","y":[133670,99411],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ti
# ...

# %% [markdown]
# **Observations:**
#
#
# We can see from the sunburst diagram that there is a gender variation in the behavior based upon the use of promocodes:
#
# **In Men:** there is chance that some men even without the promo codes may spend more.
#
# **In Women:** there is no chance that any women without the promo code would purchase more.

# %% [markdown]
# ### Q10 How does the frequency of purchases vary across different age groups?

# %%
shop[['Age' , 'Age_category']]
# Out:
#       Age        Age_category
# 0      55                 old
# 1      19        Young Adults
# 2      50  Middle-Aged Adults
# 3      21        Young Adults
# 4      45  Middle-Aged Adults
# ...   ...                 ...
# 3895   40  Middle-Aged Adults
# 3896   52                 old
# 3897   46  Middle-Aged Adults
# 3898   44  Middle-Aged Adults
# 3899   52                 old
#
# [3900 rows x 2 columns]

# %%
shop['Age_category'].unique()
# Out:
# ['old', 'Young Adults', 'Middle-Aged Adults', 'teen']
# Categories (5, object): ['child' < 'teen' < 'Young Adults' < 'Middle-Aged Adults' < 'old']

# %%
shop_group = shop.groupby('Frequency of Purchases')['Age'].sum()

# %%
px.sunburst(shop , path=['Frequency of Purchases','Age_category'] , values='Age')
# Out:
# <div>                            <div id="1a4cc60c-2b5b-423e-8e6a-1a502a8beb98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a4cc60c-2b5b-423e-8e6a-1a502a8beb98")) {                    Plotly.newPlot(                        "1a4cc60c-2b5b-423e-8e6a-1a502a8beb98",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Age=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Annually/child","Bi-Weekly/child","Every 3 Months/child","Fortnightly/child","Monthly/child","Quarterly/child","Weekly/child","Annually/teen","Bi-Weekly/teen","Every 3 Months/teen","Fortnightly/teen","Monthly/teen","Quarterly/teen","Weekly/teen","Annually/Young Adults","Bi-Weekly/Young Adults","Eve
# ...

# %% [markdown]
# **1. Age Categories Breakdown:**
#
#
# **Old (55+ years):** This group includes older adults who might have specific needs or preferences in purchasing habits. They could lean more towards essential or health-related purchases, possibly with fewer transactions per year compared to younger groups.
#
# **Young Adults (19-25 years):** Typically, younger people might make more frequent, impulse-driven purchases, especially in fashion, accessories, and entertainment.
#
# **Middle-Aged Adults (30-55 years):**  This group may include individuals who are more financially established and could make purchases more thoughtfully. They may also represent a significant portion of customers making family-related or larger purchases, like home goods, electronics, and clothing.
#
# **2. Frequency of Purchases Across Groups:**
#
#
# **Young Adults (19-25 years)** might display the highest purchase frequency due to factors such as increased social media influence, trends, and disposable income. They could make purchases for lifestyle products, fashion, or entertainment at a faster pace.
#
# **Middle-Aged Adults (30-55 years)** will likely have a moderate purchase frequency, as they might purchase more consciously and invest in quality or long-lasting products, possibly buying fewer but more expensive items per year (e.g., home appliances, cars, or insurance).
#
# **Older Adults (55+ years)** might have the lowest purchase frequency, likely driven by the prioritization of need-based purchases, such as healthcare products, and possibly lower discretionary spending. This group may also prefer more practical purchases and may shop less frequently.
#
# **3. Potential Insights:**
#
#
# **Young Adults** likely contribute to the highest frequency of purchases. They may be more active in online shopping, driven by social media, fashion trends, and impulse purchases.
#
# **Middle-Aged Adults** tend to have a more balanced shopping frequency, often making well-considered purchases that are more substantial in value. They may also represent customers who prefer in-store shopping or long-term investment products.
#
# **Older Adults** may exhibit a lower frequency of purchase due to a more selective approach to spending, possibly driven by fewer immediate needs and preferences for essential items or services.
#
# **4. Recommendations**:
#
#
# **Targeting Young Adults:** Marketers could develop strategies that encourage impulse buying, offer frequent sales, or engage this demographic through social media campaigns.
#
# **Middle-Aged Adults**: Focus on providing value-driven, quality products and services. Offering loyalty programs or discounts for repeat purchases might resonate well with this group.
#
# **Older Adults**: It's essential to highlight product functionality, customer service, and practical benefits for older adults. Offering easy-to-navigate shopping experiences and targeted promotions for essential products could help increase purchase frequency.

# %% [markdown]
# ### Q11 Are there any correlations between the size of the product and the purchase amount?

# %%
shop_group = shop.groupby('Size')['Purchase Amount (USD)'].sum().reset_index()

# %%
fig  = px.bar(shop_group , x = 'Size' , y ='Purchase Amount (USD)'  )
fig.show()
# Out:
# <div>                            <div id="c1f9350d-c0a0-4060-9623-da4044d42ad0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1f9350d-c0a0-4060-9623-da4044d42ad0")) {                    Plotly.newPlot(                        "c1f9350d-c0a0-4060-9623-da4044d42ad0",                        [{"alignmentgroup":"True","hovertemplate":"Size=%{x}<br>Purchase Amount (USD)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["L","M","S","XL"],"xaxis":"x","y":[61667,105167,40468,25779],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth
# ...

# %% [markdown]
# **1. Purchase Breakdown by Size:**
#
#
# **Medium (M)**: $105.10 (Highest)
#
# Medium size items have the highest average purchase value. This suggests that Medium is the most popular or commonly purchased size. It could represent the average body size for most consumers, leading to a higher frequency of sales in this category. Additionally, it might indicate that Medium items are priced higher or are purchased in larger quantities compared to other sizes.
#
#
# **Large (L)**: $61.60
#
# Large size items have the second-highest average purchase amount. This could indicate a moderate demand for Large sizes, but it’s not as dominant as Medium. It might suggest that customers opting for Large sizes are still making relatively high-value purchases, possibly due to higher quality or more expensive products in this size category.
#
#
# **Small (S)**: $40.40
#
# Small size items have the lowest average purchase value. This could be due to the fact that Small size products are typically more common, with potentially less variation in price. It might also indicate that customers purchasing Small sizes are either buying more affordable items or fewer items overall.
#
#
# **Extra Large (XL)**: $25.70
#
# Extra Large size items have the lowest overall purchase value. This could be because XL sizes are less commonly purchased, and the items in this size may have lower demand or may be sold at a lower price point. It's also possible that the availability of XL size items is limited compared to other sizes.
#
#
# **2. Key Insights:**
#
# Medium size dominates in terms of purchases, both in terms of quantity and average purchase value. This suggests that Medium items cater to the largest customer base, and possibly are stocked in more varieties, leading to higher sales.
# Large size purchases are still significant, indicating a healthy demand, but not as high as Medium.
# Small size purchases are likely less expensive or represent lower-value items, and it’s possible that Small is the most common size available, leading to lower overall purchase amounts per transaction.
# XL size purchases show the lowest average purchase value, which could suggest that there is a niche market for XL items, or that they are less frequently purchased.
#
# **3. Potential Reasons for Purchase Trends:**
#
# **Medium Size as the Most Popular:** This is likely the most common size for both males and females, which leads to higher sales volumes. Medium sizes might also cater to a broader demographic, increasing their market penetration.
#
# **Pricing Impact**: It's possible that Medium and Large items tend to be higher-priced, while Small and XL items are more budget-friendly or produced in lower quantities.
#
# **Consumer Behavior**: Customers purchasing Small or XL sizes might focus on specific categories, like specialty items, which are sold at a lower price point or in limited quantities.
#
#
# **4. Recommendations:**
#
# **Focus on Medium-sized Items**: Since Medium items have the highest purchase value, consider focusing your marketing and sales strategies around these products. You could increase stock availability, run promotions, or create exclusive offers for Medium size clothing.
#
# **Target Large and Extra Large Consumers**: While XL items show lower sales, improving product variety or designing more appealing options for this size could help boost sales. Offering promotions or discounts could help drive more purchases in this category.
#
# **Small-Sized Items Strategy**: For Small size clothing, consider bundling these items with other categories (like accessories or small-sized outfits) to increase the overall value per purchase, or try adjusting prices to increase demand.**

# %% [markdown]
# ### Q12 How does the presence of a discount affect the purchase decision of customers?

# %%
shop_group = shop.groupby('Discount Applied')['Purchase Amount (USD)'].sum().reset_index()

# %%
px.histogram(shop_group , x = 'Discount Applied' , y = 'Purchase Amount (USD)')
# Out:
# <div>                            <div id="5d256203-55a9-425c-8e78-86f0e53481bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d256203-55a9-425c-8e78-86f0e53481bc")) {                    Plotly.newPlot(                        "5d256203-55a9-425c-8e78-86f0e53481bc",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Discount Applied=%{x}<br>sum of Purchase Amount (USD)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["No","Yes"],"xaxis":"x","y":[133670,99411],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorba
# ...

# %%
fig = px.sunburst(shop , path = ['Gender' , 'Discount Applied'], values='Purchase Amount (USD)' , color= 'Gender')

fig.show()
# Out:
# <div>                            <div id="233c5582-e1e9-4f0e-a7c7-09bd68bdcdc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("233c5582-e1e9-4f0e-a7c7-09bd68bdcdc3")) {                    Plotly.newPlot(                        "233c5582-e1e9-4f0e-a7c7-09bd68bdcdc3",                        [{"branchvalues":"total","customdata":[["Female"],["Male"],["Male"],["Female"],["Male"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Purchase Amount (USD)=%{value}<br>parent=%{parent}<br>id=%{id}<br>Gender=%{customdata[0]}<extra></extra>","ids":["Female/No","Male/No","Male/Yes","Female","Male"],"labels":["No","No","Yes","Female","Male"],"marker":{"colors":["#636efa","#EF553B","#EF553B","#636efa","#EF553B"]},"name":"","parents":["Fema
# ...

# %% [markdown]
# **Observations:**
# We observe the same trend as we saw in question no. 9 about promo codes

# %% [markdown]
# ### Q13 Are there any specific colors that are more popular among customers?

# %%
px.histogram(shop , x = 'Color')
# Out:
# <div>                            <div id="ce0dacac-619a-455d-b1f6-5ea14c668c48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce0dacac-619a-455d-b1f6-5ea14c668c48")) {                    Plotly.newPlot(                        "ce0dacac-619a-455d-b1f6-5ea14c668c48",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Color=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Gray","Maroon","Maroon","Maroon","Turquoise","White","Gray","Charcoal","Silver","Pink","Purple","Olive","Gold","Violet","Teal","Teal","Gray","Lavender","Black","Green","Black","Charcoal","Peach","White","Green","Silver","Red","Cya
# ...

# %%
shop['Color'].value_counts().nlargest(5)
# Out:
# Color
# Olive     177
# Yellow    174
# Silver    173
# Teal      172
# Green     169
# Name: count, dtype: int64

# %% [markdown]
# **Color Breakdown:**
#
#
# **Olive (177 sales)**
# Olive is the most popular color in your dataset, indicating that this color is likely favored by a significant portion of customers. This color might appeal due to its neutral, earthy tones, which can be versatile and easy to pair with other clothing items. Olive may also have a broader appeal across different clothing categories, such as outerwear, pants, and jackets.
#
# **Yellow (174 sales)**
# Yellow comes in second with 174 sales, suggesting that while it’s not as popular as olive, it still maintains strong demand. Yellow is a bright, bold color often associated with warmth and energy, which could appeal to younger customers or those seeking statement pieces. Its popularity may also vary based on the season, with yellow often being associated with spring and summer collections.
#
# **Silver (173 sales)**
# Silver follows closely behind yellow in terms of sales, indicating that metallic tones like silver are attractive to customers. Silver items may be associated with sophistication or used in accessories such as jewelry, watches, or bags. This color might also be linked to premium or luxury products, which could explain its relatively high sales volume.
#
# **Teal (172 sales)**
# Teal is a rich, deep color that combines blue and green tones. It is slightly less popular than silver, but still maintains a solid sales presence. Teal could appeal to a range of customers who prefer more subdued yet elegant colors, and it might perform well in categories like evening wear, outerwear, or accessories.
#
# **Green (169 sales)**
# Green is the least popular color in this dataset but still holds a strong position. Green is often associated with nature, calmness, and balance, and can have wide appeal across various demographics. It might be particularly favored in more casual or outdoor-oriented clothing items.
#
# **Key Insights:**
# Olive is the Most Popular: This suggests that earthy tones and neutral colors are in demand, possibly because they’re versatile and easy to incorporate into various outfits. Olive items might also have broad appeal across different demographics, regardless of age or gender.
#
# **Bright Colors (Yellow):** Yellow performs well, likely driven by its vibrancy and association with positive emotions, but it might appeal more to specific seasonal collections (e.g., spring/summer) or younger shoppers looking for trendy and eye-catching items.
#
# **Metallic Shades (Silver)**: Silver reflects a preference for metallic and luxury items, which could be seen in high-end accessories or fashion items.
#
# **Teal and Green**: Both Teal and Green have a significant presence, but are not as dominant as the other colors. These colors may appeal to those looking for something a bit different from typical neutral or bright colors, possibly drawn by the elegance or calming nature of these hues.
#
# **Recommendations:**
#
# **Emphasize Olive:** Given its high sales volume, consider offering more products in Olive or promoting it as a staple color in collections, particularly for versatile pieces such as jackets, pants, and outerwear.
#
# **Highlight Yellow for Seasonal Campaigns**: Use Yellow in spring or summer collections to tap into the bright, cheerful associations this color has, and attract customers looking for seasonal fashion.
#
# **Focus on Silver for Premium Items**: Since Silver is performing well, consider focusing this color in luxury or premium product lines, particularly in accessories or evening wear.
#
# **Expand Teal and Green Offerings**: To further grow sales in Teal and Green, consider designing items for specific customer segments, such as those looking for more subtle, elegant clothing or accessories.

# %% [markdown]
# ### Q14 What is the average number of previous purchases made by customers?

# %%
shop['Previous Purchases'].mean()
# Out:
# 25.35153846153846

# %% [markdown]
# This indicates that, on average, each customer has made approximately 25 previous purchases. Here's an analysis based on this information:
#
# **Key Insights:**
#
# **Frequent Customers:** An average of 25.35 purchases suggests that many of your customers are repeat buyers. This indicates customer retention is strong, and your business has a solid base of loyal customers who are likely to return for additional purchases.
#
# **Potential for Upselling:** Given the number of previous purchases, there might be opportunities for upselling or cross-selling. Customers who have made multiple purchases are likely familiar with your offerings and may be more willing to try additional products or services.
#
# **Customer Engagement:** An average of 25.35 purchases could also indicate that your engagement strategies, such as promotions, discounts, or loyalty programs, are working effectively to drive repeat business.
#
# **Further Analysis:**
# **Segmentation:** It might be useful to segment customers based on their number of purchases (e.g., low-frequency vs. high-frequency buyers) to tailor marketing strategies. High-frequency buyers could be targeted with loyalty rewards or exclusive offers.
#
# **Product Performance**: Understanding what drives customers to make repeated purchases could help refine your product offerings. If certain product categories are responsible for higher repeat purchases, you may want to focus on enhancing those.
#
# **Marketing Campaigns**: For customers with fewer purchases, targeting them with personalized campaigns or follow-ups (e.g., discounts or special offers) might help convert them into more frequent buyers.
#
# **Next Steps:**
#
# **Loyalty Programs:** Strengthen or introduce customer loyalty programs to encourage even more purchases per customer.
#
# **Product Categories:** Identify products that are frequently bought together or categories where customers tend to make multiple purchases, and focus on promoting these items to increase sales volume.

# %% [markdown]
# ### Q15 Are there any noticeable differences in purchase behavior between different locations?

# %%
shop.groupby('Location')['Purchase Amount (USD)'].mean().sort_values(ascending = False)
# Out:
# Location
# Alaska            67.597222
# Pennsylvania      66.567568
# Arizona           66.553846
# West Virginia     63.876543
# Nevada            63.379310
# Washington        63.328767
# North Dakota      62.891566
# Virginia          62.883117
# Utah              62.577465
# Michigan          62.095890
# Tennessee         61.974026
# New Mexico        61.901235
# Rhode Island      61.444444
# Texas             61.194805
# Arkansas          61.113924
# Illinois          61.054348
# Mississippi       61.037500
# Massachusetts     60.888889
# Iowa              60.884058
# North Carolina    60.794872
# Wyoming           60.690141
# South Dakota      60.514286
# New York          60.425287
# Ohio              60.376623
# Montana           60.250000
# Idaho             60.075269
# Nebraska          59.448276
# New Hampshire     59.422535
# Alabama           59.112360
# California        59.000000
# Indiana           58.924051
# Georgia           58.797468
# ...

# %%
shop_group = shop.groupby('Location')['Purchase Amount (USD)'].mean().reset_index()

# %%
fig = px.bar(shop_group, x = 'Location' , y = 'Purchase Amount (USD)')
fig.show()
# Out:
# <div>                            <div id="8d62cc57-1af6-4124-a3e4-a6c60e36d7ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d62cc57-1af6-4124-a3e4-a6c60e36d7ee")) {                    Plotly.newPlot(                        "8d62cc57-1af6-4124-a3e4-a6c60e36d7ee",                        [{"alignmentgroup":"True","hovertemplate":"Location=%{x}<br>Purchase Amount (USD)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
# ...

# %% [markdown]
# **Key Insights:**
#
# **Highest Purchase Amounts:**
#
# Alaska has the highest average purchase amount at $67.60. This suggests that customers in Alaska tend to make higher-value purchases on average. This could be due to factors such as limited availability of certain goods, higher shipping costs, or a different economic profile in the state that encourages higher purchases.
# Pennsylvania and Arizona also show relatively high purchase amounts ($66.57 and $66.55, respectively), which might reflect similar factors, such as larger customer bases, a greater diversity of available products, or targeted promotions in these states.
#
#
# **States with Moderate Purchase Amounts:**
#
# **West Virginia ($63.88)** and **Nevada ($63.38)** also fall into the mid-range for average purchase amounts. This suggests that customers in these states make moderately priced purchases, potentially due to a mix of income levels or spending habits specific to the region.
#
# **Washington and North Dakota** show average purchase amounts around $63, indicating relatively consistent purchasing behavior across these locations.
#
# **Lowest Purchase Amounts:**
#
# **Connecticut has the lowest purchase amount at $54.18**, suggesting that consumers in Connecticut may spend less per transaction. This could be due to economic factors, regional market conditions, or a focus on more affordable products in the state.
#
# **Kansas ($54.56)** and **Delaware ($55.33)** also exhibit lower-than-average purchase amounts, potentially indicating a focus on budget-friendly or essential products.
#
# **Potential Factors Influencing Purchase Amounts:**
#
# **Economic Conditions**: States like Alaska and Pennsylvania could have relatively higher average incomes or cost of living, leading to higher purchasing power and larger transaction sizes.
#
# **Market Targeting**: High-value purchases in Alaska might reflect limited availability of goods and a greater willingness to spend due to fewer local alternatives. States with more competition, like California or New York, might have slightly lower average purchase amounts due to market saturation and competition.
#
# **Consumer Behavior**: The types of products in demand in these states may influence purchase amounts. For example, in West Virginia, outdoor or home improvement goods could be more common, whereas in California, lifestyle or tech products might drive different purchasing behaviors.
#
# **Promotions and Discounts:** Certain states may have more aggressive marketing or promotional strategies, which could drive higher spending. For example, states with higher purchase amounts could be the focus of seasonal sales or targeted discounts, leading to higher-than-average spending.
#
# **Recommendations:**
#
# **Target High-Spending Locations**: For states with higher average purchases (e.g., Alaska, Pennsylvania), consider offering exclusive or high-ticket items, targeted promotions, or loyalty programs to further capitalize on the spending potential.
#
# **Increase Engagement in Lower-Spending States:** In states like Connecticut or Kansas, it may be useful to offer budget-friendly products or create region-specific promotions to encourage more frequent purchases or higher transaction values.
#
# **Seasonal Strategies**: Since some states like Alaska or Arizona might have unique seasonal shopping behaviors (e.g., cold-weather gear in Alaska or summer products in Arizona), tailor your inventory and marketing campaigns based on local seasonality to increase spending.
#
# **Regional Marketing**: Use the purchase data to segment customers and create region-specific marketing campaigns. Customizing offers based on the unique needs and spending behaviors of customers in different states could improve sales performance.
#
# **Next Steps**:
#
# Further segmenting the data by product category (e.g., clothing, accessories) within these states could provide deeper insights into consumer preferences.
#
# **Analyzing demographics** (e.g., age, gender) by state could further refine your marketing strategies.
